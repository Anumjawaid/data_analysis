# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Introduction:
#
# We are going to use a subset of [US Baby Names](https://www.kaggle.com/kaggle/us-baby-names) from Kaggle.
# In the file it will be names from 2004 until 2014
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
#bn=pd.read_csv('~\Desktop\pandas_exercises-master\06_Stats\US_Baby_Names\US_Baby_Names_right.csv')

# %%
url='https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv'
bn=pd.read_csv(url)

# %%
bn.head(5)
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
bn.head(10)

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
#del bn['Unnamed: 0']
del bn["Id"]
bn.head(5)
# Out:
#       Name  Year Gender State  Count
# 0     Emma  2004      F    AK     62
# 1  Madison  2004      F    AK     48
# 2   Hannah  2004      F    AK     46
# 3    Grace  2004      F    AK     44
# 4    Emily  2004      F    AK     41

# %% [markdown]
# ### Step 6. Is there more male or female names in the dataset?

# %%
bn['Gender'].value_counts()
# Out:
# F    558846
# M    457549
# Name: Gender, dtype: int64

# %% [markdown]
# ### Step 7. Group the dataset by name and assign to names

# %%
name=bn.groupby('Name')

# %% [markdown]
# ### Step 8. How many different names exist in the dataset?

# %%
name.sum()
# Out:
#                Year  Count
# Name
# Aaban          4027     12
# Aadan          8039     23
# Aadarsh        2009      5
# Aaden        393963   3426
# Aadhav         2014      6
# Aadhya        80515    453
# Aadi          76340    307
# Aadin          2008      5
# Aadit          6029     18
# Aaditya       28116     97
# Aadya         72455    300
# Aadyn         22114     69
# Aahan          4016     14
# Aahana        30165    124
# Aahil         28152    115
# Aahna          2014      7
# Aaiden        40225    170
# Aaima          2013      5
# Aakash        38178    123
# Aalaya         2014      5
# Aalayah       34194     99
# Aaleah         4024     10
# Aaleyah       62353    262
# Aalia         18108     51
# Aaliah        42195    206
# Aalijah        6030     15
# Aaliya        86407    288
# Aaliyah     1096948  48306
# Aaliyha        8032     21
# Aalyah        32130    123
# ...             ...    ...
# Zyir          10066     25
# Zyire          2007      5
# ...

# %% [markdown]
# ### Step 9. What is the name with most occurrences?

# %%
n=name.sum()
on=n.sort_values('Count',ascending=0)
on.loc[:,'Count':].head(1)
# Out:
#         Count
# Name
# Jacob  242874

# %%
on.Count.idxmax()
# Out:
# 'Jacob'

# %%
on[on['Count']==on['Count'].max()]
# Out:
#           Year   Count
# Name
# Jacob  1141099  242874

# %% [markdown]
# ### Step 10. How many different names have the least occurrences?

# %%
len(on[on.Count == on.Count.min()])
#on[on.Count == on.Count.min()]
# Out:
# 2578

# %% [markdown]
# ### Step 11. What is the median name occurrence?

# %%
name.median()
on[on.Count == on.Count.median()]
# Out:
#              Year  Count
# Name
# Zuleima     14050     49
# Vita        14075     49
# Aziah       16073     49
# Kaedence    18088     49
# Antonina    18081     49
# Nabeel      18070     49
# Leylanie    16070     49
# Mariann     16060     49
# Iven        14062     49
# Gurshaan    14070     49
# Reghan      18073     49
# Emmaly      16075     49
# Kaelee      16060     49
# Emmanuela   18074     49
# Rubin       16055     49
# Deserae     18061     49
# Envy        16070     49
# Baily       16064     49
# Kaio        16069     49
# Maisha      14047     49
# Dahlila     14063     49
# Alara       16079     49
# Sanjuanita  10035     49
# Jaiyana     14068     49
# Fay         16072     49
# Ridwan      16082     49
# Devean       8019     49
# Kailana     14074     49
# Jaice       16098     49
# Caleah      18106     49
# ...           ...    ...
# Sameera     18083     49
# Skylie      16086     49
# Aishani     14078     49
# Carlota     14077     49
# ...

# %% [markdown]
# ### Step 12. What is the standard deviation of names?

# %%
on.Count.std()
# Out:
# 11006.0694678915

# %% [markdown]
# ### Step 13. Get a summary with the mean, min, max, std and quartiles.

# %%
on.Count.describe()
# Out:
# count     17632.000000
# mean       2008.932169
# std       11006.069468
# min           5.000000
# 25%          11.000000
# 50%          49.000000
# 75%         337.000000
# max      242874.000000
# Name: Count, dtype: float64
