# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import pprint
#import pandas_profiling 
#Euro_2012_stats_TEAM.csv

# %% [markdown]
# ### Step 2. Import the dataset Euro_2012_stats_TEAM

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
euro12=pd.read_csv("Euro_2012_stats_TEAM.csv")
print(euro12.info())
print(euro12.describe())
#print(euro12.profile_report())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 35 columns):
# Team                          17 non-null object
# Goals                         16 non-null float64
# Shots on target               16 non-null float64
# Shots off target              16 non-null float64
# Shooting Accuracy             16 non-null object
# % Goals-to-shots              16 non-null object
# Total shots (inc. Blocked)    16 non-null float64
# Hit Woodwork                  16 non-null float64
# Penalty goals                 16 non-null float64
# Penalties not scored          16 non-null float64
# Headed goals                  16 non-null float64
# Passes                        16 non-null float64
# Passes completed              16 non-null float64
# Passing Accuracy              16 non-null object
# Touches                       16 non-null float64
# Crosses                       16 non-null float64
# Dribbles                      16 non-null float64
# ...

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
euro12["Goals"]
# Out:
# 0      4.0
# 1      4.0
# 2      4.0
# 3      5.0
# 4      3.0
# 5     10.0
# 6      5.0
# 7      6.0
# 8      2.0
# 9      2.0
# 10     6.0
# 11     1.0
# 12     5.0
# 13    12.0
# 14     5.0
# 15     2.0
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# Name: Goals, dtype: float64

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
#len(euro12["Team"]) 
euro12["Team"].count()
# Out:
# 17

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(euro12.columns)
# Out:
# 35

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline=pd.DataFrame(euro12["Yellow Cards"],euro12["Red Cards"])
#discipline
#euro12["Team","Yellow Cards","Red Cards"]
#print(euro12["Yellow Cards"] ,euro12["Red Cards"])
euro12[["Yellow Cards","Red Cards","Team"]]#corect
# Out:
#     Yellow Cards  Red Cards                                               Team
# 0            9.0        0.0                                            Croatia
# 1            7.0        0.0                                     Czech Republic
# 2            4.0        0.0                                            Denmark
# 3            5.0        0.0                                            England
# 4            6.0        0.0                                             France
# 5            4.0        0.0                                            Germany
# 6            9.0        1.0                                             Greece
# 7           16.0        0.0                                              Italy
# 8            5.0        0.0                                        Netherlands
# 9            7.0        1.0                                             Poland
# 10          12.0        0.0                                           Portugal
# ...

# %%
dis=pd.DataFrame(euro12,columns=("Team","Yellow Cards","Red Cards"))
dis
#or
dis.sort_values(by=["Team","Yellow Cards","Red Cards"])
# Out:
#                                                  Team  Yellow Cards  Red Cards
# 0                                             Croatia           9.0        0.0
# 1                                      Czech Republic           7.0        0.0
# 2                                             Denmark           4.0        0.0
# 3                                             England           5.0        0.0
# 4                                              France           6.0        0.0
# 5                                             Germany           4.0        0.0
# 6                                              Greece           9.0        1.0
# 7                                               Italy          16.0        0.0
# 8                                         Netherlands           5.0        0.0
# 9                                              Poland           7.0        1.0
# 10                                           Portugal          12.0        0.0
# ...

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
sort=["Team","Red Cards","Yellow Cards"]
dis.reindex(columns=sort)
# Out:
#                                                  Team  Red Cards  Yellow Cards
# 0                                             Croatia        0.0           9.0
# 1                                      Czech Republic        0.0           7.0
# 2                                             Denmark        0.0           4.0
# 3                                             England        0.0           5.0
# 4                                              France        0.0           6.0
# 5                                             Germany        0.0           4.0
# 6                                              Greece        1.0           9.0
# 7                                               Italy        0.0          16.0
# 8                                         Netherlands        0.0           5.0
# 9                                              Poland        1.0           7.0
# 10                                           Portugal        0.0          12.0
# ...

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
dis["Yellow Cards"].mean()
# Out:
# 7.4375

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
euro12["Team"][euro12["Goals"]>6] #values selection euro12[euro12.Goals>6]
#explore filter
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %%
euro12["Team"] # apna data frame sahe se dekhe juggar na lagae
for t in euro12.Team:
   # print(t)
    v=str(t)
    t=v.startswith("G")   
    if t==True:
        print(v)
# Out:
# Germany
# Greece

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
euro12.iloc[::,:7:] #euro12.coloumns(7)
# Out:
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 6                                              Greece    5.0              8.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# 9                                              Poland    2.0             15.0
# 10                                           Portugal    6.0             22.0
# ...

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
euro12.iloc[::,:-4:]
# Out:
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 6                                              Greece    5.0              8.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# 9                                              Poland    2.0             15.0
# 10                                           Portugal    6.0             22.0
# ...

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
#euro12["Shooting Accuracy"][euro12["Team"]=="England"]
#euro12["Shooting Accuracy"][euro12["Team"]=="England"]
#euro12["Shooting Accuracy"][euro12["Team"]=="Italy"]
print(euro12["Shooting Accuracy"][euro12["Team"]=="England"],euro12["Shooting Accuracy"][euro12["Team"]=="Italy"]
,euro12["Shooting Accuracy"][euro12["Team"]=="Russia"])
eir=euro12[["Team","Shooting Accuracy"]]
eir.loc[eir["Team"].isin(["England","Italy","Russia"])]
# Out:
# 3    50.00%
# Name: Shooting Accuracy, dtype: object 7    43.00%
# Name: Shooting Accuracy, dtype: object 12    22.50%
# Name: Shooting Accuracy, dtype: object
#        Team Shooting Accuracy
# 3   England            50.00%
# 7     Italy            43.00%
# 12   Russia            22.50%

# %%
#data=pd.DataFrame(euro12,)
data=pd.read_csv("Euro_2012_stats_TEAM.csv",index_col="Team")
data.loc[["England","Italy","Russia"]]["Shooting Accuracy"]
# Out:
# Team
# England    50.00%
# Italy      43.00%
# Russia     22.50%
# Name: Shooting Accuracy, dtype: object

# %% [markdown]
# ### Step 15. Use apply method on Goal Column to make a new column called Performance, using following conditions
#
# 1. If Goals are less than or equal to 2, peformance is **Below Avg**
# 2. If Goals are more than 2 and less than or equal to 5, peformance is **Average**
# 3. If Goals are more than 5 and less than or equal to 10, peformance is **Above Average**
# 4. If Goals are more than 10 then peformance is **Excellent**

# %%
euro12["Perfomance"]=[]
for go in euro12.Goals:
    if go<=2:
        euro12["Perfomance"].append("BAvg")
        
    elif go>2 and go<=5:
        euro12["Perfomance"].append("avg")
    elif go<5 and go<=10:
        euro12["Perfomance"].append("A avg")
    elif go>10:
        euro12["Perfomance"].append("exxce")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-162-a7193993391f> in <module>()
# ----> 1 euro12["Perfomance"]=[]
#       2 for go in euro12.Goals:
#       3     if go<=2:
#       4         euro12["Perfomance"].append("BAvg")
#       5
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#    3193
# ...

# %%
euro12["Perfom"]=[]
for i in euro12.Goals:
    if i<=2:
        euro12["Perfom"].append("bavg")
    elif i>2 and i<=5:
        euro12["Perfom"].append("avg")
    elif i>5 and i<=8:
        euro12["Perfom"].append("good")
    elif i>10:
        euro12["Perfom"].append("exce")
    else :
        euro12["Perfom"].append("nan")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-224-acce57dc74a7> in <module>()
# ----> 1 euro12["Perfom"]=[]
#       2 for i in euro12.Goals:
#       3     if i<=2:
#       4         euro12["Perfom"].append("bavg")
#       5     elif i>2 and i<=5:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
# ...

# %%
euro12["Perfomance"]=["B.Avg" if g<=2  else g<=5 "avg" if g>10 "excell"for g in euro12.Goals]
# Out:
#   File "<ipython-input-225-77b39e838e8a>", line 1
#     euro12["Perfomance"]=["B.Avg" if g<=2  else g<=5 "avg" if g>10 "excell"for g in euro12.Goals]
#                                                          ^
# SyntaxError: invalid syntax

# %%
#t=euro12["Team"]
for t in euro12.Team:
   # print(t)
    v=str(t)
    t=v.startswith("G")   
    if t==True:
        print(v)
    
#str(euro12["Team"]).startswith("G")
# Out:
# Germany
# Greece

# %%
euro12["Perfomance"]=["Bavg" if g<=2 and "avg" if g<=5 and 
                      
                      for g in euro12["Goals"]]
# Out:
#   File "<ipython-input-228-fbb03dc7fca9>", line 1
#     euro12["Perfomance"]=["Bavg" if g<=2 and "avg"if g<=5 and
#                                                    ^
# SyntaxError: invalid syntax

# %%
f=lambda x:"Bellow avg"if x<=2 else "avg" if x>2 and x<=5 else "above avg" if x>5 and x<=10 else "excellent " 
data["Perf"]=data["Goals"].apply(f)
data[["Goals","Perf"]]
# Out:
#                                                     Goals        Perf
# Team
# Croatia                                               4.0         avg
# Czech Republic                                        4.0         avg
# Denmark                                               4.0         avg
# England                                               5.0         avg
# France                                                3.0         avg
# Germany                                              10.0   above avg
# Greece                                                5.0         avg
# Italy                                                 6.0   above avg
# Netherlands                                           2.0  Bellow avg
# Poland                                                2.0  Bellow avg
# Portugal                                              6.0   above avg
# Republic of Ireland                                   1.0  Bellow avg
# ...
